# %% [markdown]
#  #                                         Speech-To-Text

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from imutils import paths
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from tqdm import tqdm
from scipy import signal
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Spectrogram Libraries
from scipy.io.wavfile import read
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import Audio 
import matplotlib.patches as patches

# %%
#Spectrogram Functions
def apply_hamming_window(signal):
    # Aplica la ventana de Hamming a la señal
    window = np.hamming(len(signal))
    windowed_signal = signal * window
    return windowed_signal

def extraer_ventanas(signal, size, fs):
    #Tamano de paso
    step=int(0.010*fs)
    n_seg = int((len(signal) - size) / step)
    # extraer segmentos
    windows = [signal[i * step : i * step + size]
        for i in range(n_seg)]
    # stack (cada fila es una ventana)
    return np.vstack(windows)

def potspec(X, size, n_padded_min=0):
    # Zero padding
    if (n_padded_min == 0):
        n_padded = max(n_padded_min, int(2 ** np.ceil(np.log(size) / np.log(2))))
    else:
        n_padded = n_padded_min

    # Transformada de Fourier
    Y = np.fft.fft(X, n = n_padded)
    Y = np.absolute(Y)

    # non-redundant part
    m = int(n_padded / 2) + 1
    Y = Y[:, :m]
    Img = Y.imag
    Real = Y.real
    spec = np.sqrt(Real**2+ Img**2)

    return spec, n_padded

# %% [markdown]
# ### Spectrogram

# %%
audios_dir = r'C:\Base User Documents\UdeA\Electrónica\Semestre 2\PDS\PDS-Training Data\train\audio'

# %%
aud_dir = r'C:\Base User Documents\UdeA\Electrónica\Semestre 2\PDS\PDS-Training Data\train\audio\right\00b01445_nohash_0.wav'
file_audio = (aud_dir) # Ruta del archivo con la senal
fs1, x1 = read(file_audio) # Cargar el archivo
x1 = x1/float(max(abs(x1))) # escala la amplitud de la senal


# Graficar la senal de audio
t1 = np.arange(0, float(len(x1))/fs1, 1.0/fs1) # Vector de tiempo
plt.plot(t1, x1, color='purple') # Dibujar la grafica
# Los siguientes dos comandos dibujan las etiquetas de los ejes
plt.xlabel('Time',fontsize=18) # Etiqueta eje X
plt.ylabel('Amplitude',fontsize=18) # Etiqueta eje Y

plt.show() # Mostrar la grafica
Audio(x1, rate=fs1) # para escuchar la senal, si se desea
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Signal Spectrogram
s1 = int(40/1000 * fs1)
wind1 = extraer_ventanas(x1, s1 , fs1)

W_ham1 =[]
for i in wind1:
    W_ham1.append(apply_hamming_window(i))

# %%
espectro,nfft = potspec(W_ham1,s1, 4096)
espectro = np.flipud(10*np.log10(espectro).T)
plt.figure(figsize=(8,4))
plt.title('Espectrograma: Señal Prueba')
plt.imshow(espectro,aspect='auto', extent = [0, len(x1)/fs1, 0, fs1//2])

plt.ylabel('Frequency [Hz]', fontsize = 12)
plt.xlabel('Time [sec]', fontsize = 12)
plt.colorbar()
plt.show()

# %%
sample_rate, samples = wavfile.read(r'C:\Base User Documents\UdeA\Electrónica\Semestre 2\PDS\PDS-Short Training\train\audio\right\00b01445_nohash_0.wav')
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

plt.figure(figsize=(30,8))
plt.pcolormesh(times, frequencies, spectrogram)
plt.imshow(spectrogram)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
words = ["up", "down", "left", "right"]

# %% [markdown]
# ### Load Audio Data

# %%
data = []
labels = []
dirs = os.listdir(audios_dir)
for d in dirs:
    if d in words:
        print(d)
        files = os.listdir(os.path.join(audios_dir,d))
        audios = [f for f in files if f.endswith('.wav')]
        for file in audios:
            # load the image, swap color channels, and resize it to be a fixed
            # 224x224 pixels while ignoring aspect ratio
            #file = audios[i]
            sample_rate, samples = wavfile.read(os.path.join(audios_dir,d,file))
            frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

            # convert the image data to NumPy arrays while scaling the pixel
            # intensities to the range [0, 255]
            #image = np.array(image)/255.0
            
            # update the data and labels lists, respectively
            if spectrogram.shape[0] >= 128 and spectrogram.shape[1] >=48:
                data.append(spectrogram[:128,:48])
                labels.append(d)
            #else:
             #   print(spectrogram.shape)
# Out:
# down
# left
# right
# up

# %%
data = np.array(data)

# %% [markdown]
# ### Class distribution

# %%
values,count = np.unique(labels,return_counts=True)

# %%
import matplotlib.pyplot as plt
#plot
plt.figure(figsize=(10,5))
index = np.arange(len(words))
plt.bar(index, count)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of samples', fontsize=12)
plt.xticks(index, words, fontsize=15, rotation=60)
plt.title('No. of samples for each command')
plt.show()

# %%
labels_backup = labels

# %%
# convert the labels to NumPy arrays while scaling the pixel
labels = np.array(labels)

# %%
# perform one-hot encoding on the labels
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ls = le.fit_transform(labels)

# %%
labels_categoricals = to_categorical(ls)

# %% [markdown]
# ### Data splitting - Train,CV and Test

# %%
# partition the data into training,cross-validation and testing splits using 60%,20% and 20% of data
(trainX, testX, trainY, testY) = train_test_split(data, labels_categoricals,test_size=0.20, stratify=labels_categoricals, random_state=42)
(trainX, cvX, trainY, cvY) = train_test_split(trainX, trainY,test_size=0.25, stratify=trainY, random_state=42)

# %%
print("Train data size : ",trainX.shape)
print("Cross-Validation data size : ",cvX.shape)
print("Test data size : ",testX.shape)
# Out:
# Train data size :  (5628, 128, 48)
# Cross-Validation data size :  (1877, 128, 48)
# Test data size :  (1877, 128, 48)

# %%
del data
del labels_categoricals

# %%
from keras import backend as K

# input image dimensions
img_rows, img_cols = 128, 48

if K.image_data_format() == 'channels_first':
    trainX = trainX.reshape(trainX.shape[0], 1, img_rows, img_cols)
    testX = testX.reshape(testX.shape[0], 1, img_rows, img_cols)
    cvX = cvX.reshape(cvX.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    trainX = trainX.reshape(trainX.shape[0],img_rows, img_cols,1)
    testX = testX.reshape(testX.shape[0],img_rows, img_cols,1)
    cvX = cvX.reshape(cvX.shape[0],img_rows, img_cols,1)
    input_shape = (img_rows, img_cols,1)

# %%
print("Number of training examples :", trainX.shape[0], "and each image is of shape :",trainX.shape)
print("Number of cross validation examples :", cvX.shape[0], "and each image is of shape :",cvX.shape)
print("Number of testing examples :", testX.shape[0], "and each image is of shape :",testX.shape)
# Out:
# Number of training examples : 5628 and each image is of shape : (5628, 128, 48, 1)
# Number of cross validation examples : 1877 and each image is of shape : (1877, 128, 48, 1)
# Number of testing examples : 1877 and each image is of shape : (1877, 128, 48, 1)

# %% [markdown]
# ### VGG16 Model

# %%
#initialize the initial learning rate, number of epochs to train for and batch size
INIT_LR = 1e-3
EPOCHS = 20
batch_size = 32
num_class = len(words)
#input_shape = (224,224,3) #(513, 800, 3)

# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation
from keras.layers import Dropout,Flatten
from keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from sklearn.metrics import confusion_matrix

# %%
model = Sequential()
model.add(Conv2D(8, kernel_size=(2, 2),padding='same',activation='relu',input_shape=input_shape))
model.add(Conv2D(16, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Conv2D(32, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(Conv2D(64, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Conv2D(128, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(Conv2D(256, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_class, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 128, 48, 8)        40
#
#  conv2d_7 (Conv2D)           (None, 128, 48, 16)       528
#
#  max_pooling2d_3 (MaxPoolin  (None, 64, 24, 16)        0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 64, 24, 16)        64
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64, 24, 16)        0
#
#  conv2d_8 (Conv2D)           (None, 64, 24, 32)        2080
#
#  conv2d_9 (Conv2D)           (None, 64, 24, 64)        8256
#
#  max_pooling2d_4 (MaxPoolin  (None, 32, 12, 64)        0
#  g2D)
#
#  batch_normalization_4 (Bat  (None, 32, 12, 64)        256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 32, 12, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 32, 12, 128)       32896
#
#  conv2d_11 (Conv2D)          (None, 32, 12, 256)       131328
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 6, 256)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 16, 6, 256)        1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 16, 6, 256)        0
#
#  flatten_1 (Flatten)         (None, 24576)             0
#
#  dense_2 (Dense)             (None, 256)               6291712
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 6469212 (24.68 MB)
# Trainable params: 6468540 (24.68 MB)
# Non-trainable params: 672 (2.62 KB)
# _________________________________________________________________

# %%
#from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=INIT_LR)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(trainX, trainY, batch_size=batch_size, epochs=EPOCHS, verbose=1, callbacks=[es,mc],validation_data=(cvX, cvY))
# Out:
# Epoch 1/20
# 176/176 [==============================] - ETA: 0s - loss: 2.0696 - accuracy: 0.2838WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 44s 241ms/step - loss: 2.0696 - accuracy: 0.2838 - val_loss: 1.3880 - val_accuracy: 0.2898
# Epoch 2/20
# 176/176 [==============================] - ETA: 0s - loss: 1.4157 - accuracy: 0.2848WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 43s 246ms/step - loss: 1.4157 - accuracy: 0.2848 - val_loss: 1.3988 - val_accuracy: 0.3138
# Epoch 3/20
# 176/176 [==============================] - ETA: 0s - loss: 1.3618 - accuracy: 0.3236WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 43s 243ms/step - loss: 1.3618 - accuracy: 0.3236 - val_loss: 1.3897 - val_accuracy: 0.2674
# Epoch 4/20
# 176/176 [==============================] - ETA: 0s - loss: 1.3155 - accuracy: 0.3710WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 43s 242ms/step - loss: 1.3155 - accuracy: 0.3710 - val_loss: 1.2706 - val_accuracy: 0.4267
# Epoch 5/20
# 176/176 [==============================] - ETA: 0s - loss: 1.2509 - accuracy: 0.4138WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 43s 243ms/step - loss: 1.2509 - accuracy: 0.4138 - val_loss: 1.3034 - val_accuracy: 0.3660
# Epoch 6/20
# 176/176 [==============================] - ETA: 0s - loss: 1.2003 - accuracy: 0.4440WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 43s 242ms/step - loss: 1.2003 - accuracy: 0.4440 - val_loss: 1.1323 - val_accuracy: 0.4981
# Epoch 7/20
# 176/176 [==============================] - ETA: 0s - loss: 1.1196 - accuracy: 0.4847WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 238ms/step - loss: 1.1196 - accuracy: 0.4847 - val_loss: 1.3529 - val_accuracy: 0.4219
# Epoch 8/20
# 176/176 [==============================] - ETA: 0s - loss: 1.0741 - accuracy: 0.5258WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 40s 229ms/step - loss: 1.0741 - accuracy: 0.5258 - val_loss: 1.0005 - val_accuracy: 0.6020
# Epoch 9/20
# 176/176 [==============================] - ETA: 0s - loss: 1.0196 - accuracy: 0.5444WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 40s 229ms/step - loss: 1.0196 - accuracy: 0.5444 - val_loss: 1.4111 - val_accuracy: 0.4150
# Epoch 10/20
# 176/176 [==============================] - ETA: 0s - loss: 0.9576 - accuracy: 0.5853WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 41s 231ms/step - loss: 0.9576 - accuracy: 0.5853 - val_loss: 0.8998 - val_accuracy: 0.6867
# Epoch 11/20
# 176/176 [==============================] - ETA: 0s - loss: 0.9203 - accuracy: 0.6027WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 41s 231ms/step - loss: 0.9203 - accuracy: 0.6027 - val_loss: 1.2357 - val_accuracy: 0.4422
# Epoch 12/20
# 176/176 [==============================] - ETA: 0s - loss: 0.8682 - accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 40s 229ms/step - loss: 0.8682 - accuracy: 0.6429 - val_loss: 0.7109 - val_accuracy: 0.7453
# Epoch 13/20
# 176/176 [==============================] - ETA: 0s - loss: 0.8032 - accuracy: 0.6731WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 239ms/step - loss: 0.8032 - accuracy: 0.6731 - val_loss: 1.2894 - val_accuracy: 0.3356
# Epoch 14/20
# 176/176 [==============================] - ETA: 0s - loss: 0.7866 - accuracy: 0.6821WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 237ms/step - loss: 0.7866 - accuracy: 0.6821 - val_loss: 1.1180 - val_accuracy: 0.4880
# Epoch 15/20
# 176/176 [==============================] - ETA: 0s - loss: 0.7747 - accuracy: 0.6949WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 41s 235ms/step - loss: 0.7747 - accuracy: 0.6949 - val_loss: 1.1683 - val_accuracy: 0.4113
# Epoch 16/20
# 176/176 [==============================] - ETA: 0s - loss: 0.7151 - accuracy: 0.7168WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 41s 235ms/step - loss: 0.7151 - accuracy: 0.7168 - val_loss: 1.2890 - val_accuracy: 0.3623
# Epoch 17/20
# 176/176 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.7329WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 236ms/step - loss: 0.6915 - accuracy: 0.7329 - val_loss: 1.5082 - val_accuracy: 0.3596
# Epoch 18/20
# 176/176 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.7377WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 237ms/step - loss: 0.6646 - accuracy: 0.7377 - val_loss: 1.4819 - val_accuracy: 0.3191
# Epoch 19/20
# 176/176 [==============================] - ETA: 0s - loss: 0.6621 - accuracy: 0.7335WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 239ms/step - loss: 0.6621 - accuracy: 0.7335 - val_loss: 1.2295 - val_accuracy: 0.3879
# Epoch 20/20
# 176/176 [==============================] - ETA: 0s - loss: 0.6271 - accuracy: 0.7598WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 176/176 [==============================] - 42s 240ms/step - loss: 0.6271 - accuracy: 0.7598 - val_loss: 1.3628 - val_accuracy: 0.3895

# %%
# plot the training loss
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
#plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
#plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Train/CV Loss on Speech-To-Text Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")

# %%
# plot the training accuracy
N = EPOCHS
#plt.style.use("ggplot")
plt.figure()
#plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
#plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Train and CV Accuracy on Speech-To-Text Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
best_acc = max(history.history["accuracy"])*100
best_val_acc = max(history.history["val_accuracy"])*100

# %%
# make predictions on the testing set
predIdxs = model.predict(testX, batch_size=batch_size)
# Out:
# 59/59 [==============================] - 2s 37ms/step

# %%
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# %%
def plot_Confusion_Matrix(actual_labels,predict_labels,title):
    """This function plot the confusion matrix"""
    cm = confusion_matrix(actual_labels, predict_labels)
    classNames = words
    cm_data = pd.DataFrame(cm,index = classNames,
                  columns = classNames)
    plt.figure(figsize = (8,8))
    sns.heatmap(cm_data, annot=True,fmt="d")
    plt.title(title)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()
    return cm

# %%
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = plot_Confusion_Matrix(testY.argmax(axis=1), predIdxs,"Confusion Matrix")

# %%
tot = cm[0][0]
for i in range(1,len(words)):
    tot+= cm[i][i]
test = round((tot/testX.shape[0])*100,2)

# %% [markdown]
# ## Results

# %%
from prettytable import PrettyTable
ptable = PrettyTable()
ptable.title = " Model Results "
ptable.field_names = ["Mode",'Sample size','Accuracy']
ptable.add_row(["Train",trainX.shape[0], round(best_acc,2)])
ptable.add_row(["Cross-Validation",cvX.shape[0],round(best_val_acc,2)])
ptable.add_row(["Test",testX.shape[0],test])
print(ptable)
# Out:
# +-------------------------------------------+
# |               Model Results               |
# +------------------+-------------+----------+
# |       Mode       | Sample size | Accuracy |
# +------------------+-------------+----------+
# |      Train       |     5628    |  75.98   |
# | Cross-Validation |     1877    |  74.53   |
# |       Test       |     1877    |  37.88   |
# +------------------+-------------+----------+
